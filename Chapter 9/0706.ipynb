# %% [markdown]
# <a href="https://colab.research.google.com/github/CallmeQuita/SIC/blob/main/Chapter%209/0706.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Phân lớp chữ viết tay với MNIST

# %%
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
import tensorflow_datasets as tfds # Tải bộ thư viện với pip
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Tải dữ liệu với Bộ datasets

# %%
datasets = tfds.load('mnist', shuffle_files=False, as_supervised=False)
mnist_train_orig, mnist_test_orig = datasets['train'], datasets['test']
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/mnist/3.0.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/mnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/mnist/incomplete.TAM8BV_3.0.1/mnist-train.tfrecord*...:   0%|          | 0…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/mnist/incomplete.TAM8BV_3.0.1/mnist-test.tfrecord*...:   0%|          | 0/…
# Dataset mnist downloaded and prepared to /root/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.

# %%
buffer_size = 10000
batch_size = 64
num_epochs = 20

# %%
mnist_train = mnist_train_orig.map(
    lambda item: (tf.cast(item['image'], tf.float32) / 255.0,
                  tf.cast(item['label'], tf.int32))
)

mnist_test = mnist_test_orig.map(
    lambda item: (tf.cast(item['image'], tf.float32) / 255.0,
                  tf.cast(item['label'], tf.int32))
)
tf.random.set_seed(1)
mnist_train = mnist_train.shuffle(buffer_size = buffer_size, reshuffle_each_iteration=False)
mnist_valid = mnist_train.take(10000).batch(batch_size)
mnist_train = mnist_train.skip(10000).batch(batch_size)

# %% [markdown]
# ## Xây dựng mạng Neural Network

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(filters=32,kernel_size=(5,5),strides=(1,1),padding='same',data_format='channels_last',
          name='conv_1', activation = 'relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2),name='pool_1'))

# %%
model.add(tf.keras.layers.Conv2D(filters=64,kernel_size=(5,5),strides=(1,1), padding='same', name='conv_2', activation='relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size = (2,2), name='pool_2'))

# %%
model.compute_output_shape(input_shape=(16,28,28,1))
# Out:
# (16, 7, 7, 64)

# %%
model.add(tf.keras.layers.Flatten())
model.compute_output_shape(input_shape=(16,28,28,1))
# Out:
# (16, 3136)

# %%
model.add(tf.keras.layers.Dense(units=1024, name='fc_1',activation='relu'))
model.add(tf.keras.layers.Dropout(rate=0.5))
model.add(tf.keras.layers.Dense(units=10,name='fc_2',activation='softmax'))

# %%
tf.random.set_seed(1)
model.build(input_shape=(None,28,28,1))
model.compile(optimizer = tf.keras.optimizers.Adam(),
              loss = ['sparse_categorical_crossentropy'],
              metrics=['accuracy'])

# %%
history = model.fit(mnist_train,epochs = num_epochs, validation_data = mnist_valid, shuffle=True)
# Out:
# Epoch 1/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8996 - loss: 0.3173 - val_accuracy: 0.9850 - val_loss: 0.0499
# Epoch 2/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9850 - loss: 0.0485 - val_accuracy: 0.9867 - val_loss: 0.0448
# Epoch 3/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9893 - loss: 0.0326 - val_accuracy: 0.9879 - val_loss: 0.0385
# Epoch 4/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9926 - loss: 0.0236 - val_accuracy: 0.9896 - val_loss: 0.0365
# Epoch 5/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9940 - loss: 0.0177 - val_accuracy: 0.9898 - val_loss: 0.0411
# Epoch 6/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9956 - loss: 0.0158 - val_accuracy: 0.9873 - val_loss: 0.0570
# Epoch 7/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9943 - loss: 0.0163 - val_accuracy: 0.9892 - val_loss: 0.0427
# Epoch 8/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9960 - loss: 0.0118 - val_accuracy: 0.9904 - val_loss: 0.0439
# Epoch 9/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9969 - loss: 0.0094 - val_accuracy: 0.9903 - val_loss: 0.0441
# Epoch 10/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9973 - loss: 0.0081 - val_accuracy: 0.9908 - val_loss: 0.0509
# Epoch 11/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9969 - loss: 0.0101 - val_accuracy: 0.9901 - val_loss: 0.0460
# Epoch 12/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9973 - loss: 0.0074 - val_accuracy: 0.9905 - val_loss: 0.0497
# Epoch 13/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9974 - loss: 0.0075 - val_accuracy: 0.9905 - val_loss: 0.0488
# Epoch 14/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9978 - loss: 0.0065 - val_accuracy: 0.9900 - val_loss: 0.0569
# Epoch 15/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9979 - loss: 0.0075 - val_accuracy: 0.9886 - val_loss: 0.0666
# Epoch 16/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9980 - loss: 0.0069 - val_accuracy: 0.9882 - val_loss: 0.0790
# Epoch 17/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9975 - loss: 0.0093 - val_accuracy: 0.9914 - val_loss: 0.0565
# Epoch 18/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9990 - loss: 0.0038 - val_accuracy: 0.9899 - val_loss: 0.0688
# Epoch 19/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9982 - loss: 0.0046 - val_accuracy: 0.9905 - val_loss: 0.0756
# Epoch 20/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9982 - loss: 0.0079 - val_accuracy: 0.9908 - val_loss: 0.0587

# %%
hist = history.history
x_arr = np.arange(len(hist['loss']))+1
fig = plt.figure(figsize=(12,4))
ax = fig.add_subplot(1,2,1)
ax.plot(x_arr,hist['loss'],'o',label='Train loss')
ax.plot(x_arr,hist['val_loss'],'--<', label='Validation loss')
ax.set_xlabel('Epoch', size = 15)
ax.set_ylabel('Loss',size = 15)
ax.legend(fontsize=15)
ax = fig.add_subplot(1,2,2)
ax.plot(x_arr,hist['accuracy'],'-o',label='Train acc.')
ax.plot(x_arr,hist['val_accuracy'],'--<', label='Validation acc.')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size = 15)
ax.set_ylabel('Accuracy',size=15)
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
test_results = model.evaluate(mnist_test.batch(20))
print('\n test accuracy {:.2f}%'.format(test_results[1]*100))
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9922 - loss: 0.0304
#
#  test accuracy 99.16%

# %% [markdown]
# ## Dự đoán nhãn dựa trên bộ test

# %%
batch_test = next(iter(mnist_test.batch(12)))
preds = model(batch_test[0])
tf.print(preds.shape)
preds =tf.argmax(preds,axis=1)
print(preds)
# Vẽ ảnh
fig = plt.figure(figsize=(12,4))
for i in range(12):
    ax = fig.add_subplot(2,6,i+1)
    ax.set_xticks([])
    ax.set_yticks([])
    img = batch_test[0][i,:,:,0]
    ax.imshow(img,cmap='gray_r')
    ax.text(0.9,0.1,'{}'.format(preds[i]),size=15,color='b',horizontalalignment='center', verticalalignment='center',
    transform = ax.transAxes)
plt.show()
# Out:
# TensorShape([12, 10])
# tf.Tensor([2 0 4 8 7 6 0 6 3 1 8 0], shape=(12,), dtype=int64)
